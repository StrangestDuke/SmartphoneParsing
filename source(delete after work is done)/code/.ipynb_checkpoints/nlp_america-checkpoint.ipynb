# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
with open ("data/wiki_usa.txt", "r") as f:
    text = f.read()

# %%
print(text)
# Out:
# {{другие значения}}
# {{о|государстве, часто именуемом Америкой|Соединённые Штаты Америки}}
# {{Материк
#  |Название              = Америка
#  |Изображение           = Americas (orthographic projection).svg
#   |Подпись              = Америка на карте западного полушария
#  |Территория            = 42 549 000
#  |Население             = 953,7 млн (июль 2013)<ref name="PopulationofAmericas">{{cite web |url=https://www.cia.gov/library/publications/the-world-factbook/rankorder/2119rank.html |title=The World Factbook |publisher=Central Intelligence Agency |date=2013 |accessdate=2013-09-30 |archive-date=2011-09-27 |archive-url=https://web.archive.org/web/20110927165947/https://www.cia.gov/library/publications/the-world-factbook/rankorder/2119rank.html |deadlink=yes }}</ref>
#   |Плотность населения  =
#  |Этнохороним           = [[американцы]]
#  |Государств            = 35
#  |список стран          = Список государств и зависимых территорий Северной Америки
# ...
