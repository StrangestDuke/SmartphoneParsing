# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle 
import plotly.express as px

# %%
with open("../db/ready_data.pkl", 'rb') as f:
    df = pickle.load(f)

# %%
"""
Для кластеризации были продукты, что не имели в себе каких-либо NaN значений, после
чего были прокластерезированны и разделены а 4 кластера методом KMeans

Названия были заменены на названия компаний издателей, для проведения кластеризации
Цена указанная в таблицы - находится в рублях
Колонка rec_proc - является процентом пользователей, что рекомендовали данный продукт(из тех людей
что купили продукт)
ОЗУ И ПЗУ находятся в гигабайтах и в продуктах был взят именно минимальный размер памяти
для того или иного телефона.
Батарея находится в значениях мА\ч
Камера находится в мегапикселях

Дополнительно к характеристикам, что были указаны в ТЗ были добавлены:
ОС, ОЗУ, ПЗУ, Диагональ, Камера.
Все это было выбранно как важные параметры характеристик телефона, что сказываются на стоимость
телефона, выбор потенциальных клиентов, а значит и прибыли различных кампаний.

"""
# Out:
# '\nДля кластеризации были продукты, что не имели в себе каких-либо NaN значений, после\nчего были прокластерезированны и разделены а 4 кластера методом KMeans\n\nНазвания были заменены на названия компаний издателей, для проведения кластеризации\nЦена указанная в таблицы - находится в рублях\nКолонка rec_proc - является процентом пользователей, что рекомендовали данный продукт(из тех людей\nчто купили продукт)\nОЗУ И ПЗУ находятся в гигабайтах и в продуктах был взят именно минимальный размер памяти\nдля того или иного телефона.\nБатарея находится в значениях мА\\ч\nКамера находится в мегапикселях\n\nДополнительно к характеристикам, что были указаны в ТЗ были добавлены:\n\n'

# %%
df.head(30)
# Out:
#         name  price  sales  stars  rec_proc  review_num          OS  RAM  ROM  \
# 0      Apple  69676    642    4.9       0.9          91      iOS 17    6  128
# 1     Google  41093     92    4.9       0.9          68  Android 12    8  128
# 2  Blackview  23733     39    4.8       0.9          27  Android 12   12  256
# 3    Oukitel  22799    436    4.7       0.9         309  Android 12    8  256
# 4    Ulefone  21943     28    4.5       0.8          16  Android 13   16  256
#
#    diag    bat  cam  kmeans_4
# 0  6.10   3349   48         2
# 1  6.40   4614   50         2
# 2  6.70  15080   50         2
# 3  6.78  21000   64         2
# 4  6.58   9600   64         1

# %%
plt.figure(figsize=(20,20))
col_cat = df.select_dtypes(exclude=['object']).columns.tolist()
corr = df[col_cat].corr()
sns.heatmap(corr, cmap=sns.color_palette("ch:s=-.2,r=.6", as_cmap=True),annot=True)
plt.show()

# %%
"""

Как можно увидеть из графика корреляций - наиболее влияют на продажи - количество обзоров
Имеется зависимость между количеством ПЗУ и ОЗУ в телефоне
Диагональ и камера - значительно сказываются на стоимости телефона
Количество звезд телефона в общем - сказывается на стоимости, скорее всего из-за того, вокруг
некоторых продуктов образуется некоторый культ, что восхваляет некоторые продукты.


"""

# %%
"""
После проведения кластеризации в полученных продуктах были выделены 3 группы:
Телефоны средней категории(телефоны что не имеют завышенных цен и имеют среднее железо)
Телефоны дешёвой категории(телефоны, что имеют низкие цены и имеют хорошее железо)
Телефоны завышенной цены(телефоны, что имеют большую цену, однако не имеют железа, что оправдывает её)
"""
# Out:
# '\nПосле проведения кластеризации в полученных продуктах были выделены 3 группы:\nТелефоны средней категории(телефоны что не имеют завышенных цен и имеют среднее железо)\nТелефоны дешёвой категории(телефоны, что имеют низкие цены и имеют хорошее железо)\nТелефоны завышенной цены(телефоны, что имеют большую цену, однако не имеют железа, что оправдывает её)\n'

# %%
for i in range(0,3):
    meow = df[df['kmeans_4']== i]
    print(meow.head(20))
# Out:
#       name  price  sales  stars  rec_proc  review_num          OS  RAM  ROM  \
# 6   Xiaomi  17898    968    4.8       0.9         682  Android 11    6  128
# 7   Xiaomi  15075     97    4.6       0.8          68  Android 11    4  128
# 10  Xiaomi  14821     46    4.8       0.9          34  Android 10    6  128
# 19  Xiaomi   9641    106    4.7       0.9          59  Android 11    4   64
# 20  Xiaomi   9498    282    4.6       0.9         351  Android 10    4   64
#
#     diag   bat  cam  kmeans_4
# 6   6.67  4500  108         0
# 7   6.60  5000   50         0
# 10  6.53  5000   48         0
# 19  6.53  5000   13         0
# 20  6.53  5000   13         0
#          name  price  sales  stars  rec_proc  review_num          OS  RAM  \
# 4     Ulefone  21943     28    4.5       0.8          16  Android 13   16
# 5   Blackview  21786     72    4.9       0.9          48  Android 13   24
# 11      Cubot  15598    276    4.6       0.9         148  Android 13   24
# 12      Cubot  14580    262    4.7       0.9         153  Android 13    8
# 14      Cubot  11574   1000    4.6       0.9         964  Android 13    8
# 18      Cubot   9750    430    4.7       0.9         311  Android 13    8
# 21      Cubot   9063     29    4.6       0.8          16  Android 13   12
# 24      Cubot   8071    243    4.7       0.9         146  Android 13   12
#
#     ROM  diag    bat  cam  kmeans_4
# 4   256  6.58   9600   64         1
# 5   256  6.67   5050  108         1
# 11  256  6.58   5200  100         1
# 12  256  6.50  10600   48         1
# 14  256  6.58   5200   48         1
# 18  256  6.56   5200   50         1
# 21  256  6.56   5200   50         1
# 24  128  6.56   5200   50         1
#          name  price  sales  stars  rec_proc  review_num          OS  RAM  \
# 0       Apple  69676    642    4.9       0.9          91      iOS 17    6
# 1      Google  41093     92    4.9       0.9          68  Android 12    8
# 2   Blackview  23733     39    4.8       0.9          27  Android 12   12
# 3     Oukitel  22799    436    4.7       0.9         309  Android 12    8
# 8   Blackview  16661    172    4.8       0.9         136  Android 12    6
# 15  Blackview  11266    162    4.8       0.9         134  Android 12    8
# 17      Cubot  10311    447    4.6       0.9         171  Android 12    6
# 25      Oscal   8018    476    4.7       0.9         370  Android 12    6
# 26  Blackview   7621     66    4.9       0.9          42  Android 13    4
#
#     ROM  diag    bat  cam  kmeans_4
# 0   128  6.10   3349   48         2
# 1   128  6.40   4614   50         2
# 2   256  6.70  15080   50         2
# 3   256  6.78  21000   64         2
# 8   128  6.58  13000   12         2
# 15  128  6.50   4480   50         2
# 17  128  4.50   3000   20         2
# 25  128  6.60   5180   50         2
# 26  128  6.50   5180   13         2

# %%
companies = df['name'].unique()

# %%
#Функция для перебора продуктов по ценам и кампаниям
def show_difference_in_price_with_companies(df):
    for n in companies:
        #Копирование датасета по кампаниям
        df_com = df[df["name"] == n]
        print("Количество Телефонов от данной кампании:")
        print("{}: {}".format(n,len(df_com[df_com["name"] == n]))),
        sns.scatterplot(df_com[(df_com["name"] == n)],y='sales', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_price_with_companies(df)
# Out:
# Количество Телефонов от данной кампании:
# Apple: 1
# Количество Телефонов от данной кампании:
# Google: 1
# Количество Телефонов от данной кампании:
# Blackview: 6
# Количество Телефонов от данной кампании:
# Oukitel: 1
# Количество Телефонов от данной кампании:
# Ulefone: 4
# Количество Телефонов от данной кампании:
# Xiaomi: 5
# Количество Телефонов от данной кампании:
# Cubot: 8
# Количество Телефонов от данной кампании:
# Oscal: 1

# %%
#Функция для перебора продуктов по ценам, продажам и кластерам
def show_difference_in_price_with_clusters(df):
    for n in range(0,3):
        #Копирование датасета по кампаниям
        df_com = df[df["kmeans_4"] == n]
        print("Количество Телефонов в данном кластере:")
        print("{}: {}".format(n,len(df_com[df_com["kmeans_4"] == n]))),
        sns.scatterplot(df_com[(df_com["kmeans_4"] == n)], x="price", y='sales',alpha=0.6,label=str(n)).set(title='Цены кластера {}'.format(n))
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_price_with_clusters(df)
# Out:
# Количество Телефонов в данном кластере:
# 0: 5
# Количество Телефонов в данном кластере:
# 1: 8
# Количество Телефонов в данном кластере:
# 2: 9

# %%
"""

Как видно из графиков представленных выше - компания что предоставляет телефоны - разительно
сказывается на цене конечного продукта, что поставляется пользователям.

"""
# Out:
# '\n\nКак видно из графиков представленных выше - компания что предоставляет телефоны - разительно\nсказывается на цене конечного продукта, что поставляется пользователям.\n\n'

# %%
#Функция для перебора продуктов по ценам и кампаниям
def show_difference_in_cameras_with_companies(df):
    cameras = df['cam'].unique()
    for n in companies:
        #Копирование датасета по кампаниям
        df_com = df[df["name"] == n]
        print("Количество Телефонов c камерами различных характеристик:")
        print("{}: {}".format(n,len(df_com[df_com["cam"] == n]))),
        sns.scatterplot(df_com[(df_com["name"] == n)],y='cam', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний, с камерами различных характеристик')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_cameras_with_companies(df)
# Out:
# Количество Телефонов c камерами различных характеристик:
# Apple: 0
# Количество Телефонов c камерами различных характеристик:
# Google: 0
# Количество Телефонов c камерами различных характеристик:
# Blackview: 0
# Количество Телефонов c камерами различных характеристик:
# Oukitel: 0
# Количество Телефонов c камерами различных характеристик:
# Ulefone: 0
# Количество Телефонов c камерами различных характеристик:
# Xiaomi: 0
# Количество Телефонов c камерами различных характеристик:
# Cubot: 0
# Количество Телефонов c камерами различных характеристик:
# Oscal: 0

# %%
#Функция для перебора продуктов по ценам и кампаниям
def show_difference_in_cameras_with_clusters(df):
    cameras = df['cam'].unique()
    for n in range(0,3):
        #Копирование датасета по кампаниям
        df_com = df[df["kmeans_4"] == n]
        print("Количество Телефонов c камерами различных характеристик:")
        print("{}: {}".format(n,len(df_com[df_com["kmeans_4"] == n]))),
        sns.scatterplot(df_com[(df_com["kmeans_4"] == n)],y='cam', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний, с камерами различных характеристик')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_cameras_with_clusters(df)
# Out:
# Количество Телефонов c камерами различных характеристик:
# 0: 5
# Количество Телефонов c камерами различных характеристик:
# 1: 8
# Количество Телефонов c камерами различных характеристик:
# 2: 9

# %%
"""

Камера разительно не сказывается на стоимости конечного продукта, если не говорить о телефонах
дешёвого сегмента

"""
# Out:
# '\n\nКамера разительно не сказывается на стоимости конечного продукта, если не говорить о телефонах\nдешёвого сегмента\n\n'

# %%
#Функция для перебора продуктов по обзорам, ценам и кампаниям
def show_difference_in_sales_with_companies(df):
    for n in companies:
        #Копирование датасета по кампаниям
        df_com = df[df["name"] == n]
        print("Количество Телефонов с различным количеством отзывов:")
        print("Телефон {}: количество отзывов {}".format(n,len(df_com[df_com["name"] == n]))),
        sns.scatterplot(df_com[(df_com["name"] == n)],y='review_num', x="sales",alpha=0.9,label=str(n)).set(title='Цены кампаний')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_sales_with_companies(df)
# Out:
# Количество Телефонов с различным количеством отзывов:
# Телефон Apple: количество отзывов 1
# Количество Телефонов с различным количеством отзывов:
# Телефон Google: количество отзывов 1
# Количество Телефонов с различным количеством отзывов:
# Телефон Blackview: количество отзывов 6
# Количество Телефонов с различным количеством отзывов:
# Телефон Oukitel: количество отзывов 1
# Количество Телефонов с различным количеством отзывов:
# Телефон Ulefone: количество отзывов 4
# Количество Телефонов с различным количеством отзывов:
# Телефон Xiaomi: количество отзывов 5
# Количество Телефонов с различным количеством отзывов:
# Телефон Cubot: количество отзывов 8
# Количество Телефонов с различным количеством отзывов:
# Телефон Oscal: количество отзывов 1

# %%
#Функция для перебора продуктов по обзорам, ценам и кампаниям
def show_difference_in_sales_with_clusters(df):
    for n in range(0,3):
        #Копирование датасета по кампаниям
        df_com = df[df["kmeans_4"] == n]
        print("Количество Телефонов c разным количеством отзывов")
        print("{}: {}".format(n,len(df_com[df_com["kmeans_4"] == n]))),
        sns.scatterplot(df_com[(df_com["kmeans_4"] == n)],y='review_num', x="sales",alpha=0.9,label=str(n)).set(title='Цены кампаний, с камерами различных характеристик')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_sales_with_clusters(df)
# Out:
# Количество Телефонов c разным количеством отзывов
# 0: 5
# Количество Телефонов c разным количеством отзывов
# 1: 8
# Количество Телефонов c разным количеством отзывов
# 2: 9

# %%
"""

Количество отзывов, что оставляют пользователи - крайне сильно сказываются на продажах телефона
в сети джум. Однако тут может быть и взаимосвязь сказываться в том, что потенциальные покупатели
знали о продукте ещё до его приобретения из других источников. Уже из этого можно сделать вывод,
что рекламые кампании, а так-же общее слово людей о продукте - разительно повышает его популяроность,
а в общем итоге - продажи

"""
# Out:
# '\n\nКоличество отзывов, что оставляют пользователи - крайне сильно сказываются на продажах телефона\nв сети джум. Однако тут может быть и взаимосвязь сказываться в том, что потенциальные покупатели\nзнали о продукте ещё до его приобретения из других источников. Уже из этого можно сделать вывод,\nчто рекламые кампании, а так-же общее слово людей о продукте - разительно повышает его популяроность,\nа в общем итоге - продажи\n\n'

# %%
#Функция для перебора продуктов по ОЗУ, ценам и кампаниям
def show_difference_in_RAM_with_companies(df):
    for n in companies:
        #Копирование датасета по кампаниям
        df_com = df[df["name"] == n]
        print("Количество Телефонов с ОЗУ различных характеристик:")
        print("Телефон {}: количество отзывов {}".format(n,len(df_com[df_com["name"] == n]))),
        sns.scatterplot(df_com[(df_com["name"] == n)],y='RAM', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_RAM_with_companies(df)
# Out:
# Количество Телефонов с ОЗУ различных характеристик:
# Телефон Apple: количество отзывов 1
# Количество Телефонов с ОЗУ различных характеристик:
# Телефон Google: количество отзывов 1
# Количество Телефонов с ОЗУ различных характеристик:
# Телефон Blackview: количество отзывов 6
# Количество Телефонов с ОЗУ различных характеристик:
# Телефон Oukitel: количество отзывов 1
# Количество Телефонов с ОЗУ различных характеристик:
# Телефон Ulefone: количество отзывов 4
# Количество Телефонов с ОЗУ различных характеристик:
# Телефон Xiaomi: количество отзывов 5
# Количество Телефонов с ОЗУ различных характеристик:
# Телефон Cubot: количество отзывов 8
# Количество Телефонов с ОЗУ различных характеристик:
# Телефон Oscal: количество отзывов 1

# %%
#Функция для перебора продуктов по ОЗУ, ценам и кампаниям
def show_difference_in_RAM_with_clusters(df):
    for n in range(0,3):
        #Копирование датасета по кампаниям
        df_com = df[df["kmeans_4"] == n]
        print("Количество Телефонов c ОЗУ различных характеристик:")
        print("{}: {}".format(n,len(df_com[df_com["kmeans_4"] == n]))),
        sns.scatterplot(df_com[(df_com["kmeans_4"] == n)],y='RAM', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний, с камерами различных характеристик')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_RAM_with_clusters(df)
# Out:
# Количество Телефонов c ОЗУ различных характеристик:
# 0: 5
# Количество Телефонов c ОЗУ различных характеристик:
# 1: 8
# Количество Телефонов c ОЗУ различных характеристик:
# 2: 9

# %%
#Функция для перебора продуктов по диагоналям, ценам и кампаниям
def show_difference_in_diag_with_companies(df):
    for n in companies:
        #Копирование датасета по кампаниям
        df_com = df[df["name"] == n]
        print("Количество Телефонов с Диагональю различных характеристик:")
        print("Телефон {}: количество отзывов {}".format(n,len(df_com[df_com["name"] == n]))),
        sns.scatterplot(df_com[(df_com["name"] == n)],y='diag', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_diag_with_companies(df)
# Out:
# Количество Телефонов с Диагональю различных характеристик:
# Телефон Apple: количество отзывов 1
# Количество Телефонов с Диагональю различных характеристик:
# Телефон Google: количество отзывов 1
# Количество Телефонов с Диагональю различных характеристик:
# Телефон Blackview: количество отзывов 6
# Количество Телефонов с Диагональю различных характеристик:
# Телефон Oukitel: количество отзывов 1
# Количество Телефонов с Диагональю различных характеристик:
# Телефон Ulefone: количество отзывов 4
# Количество Телефонов с Диагональю различных характеристик:
# Телефон Xiaomi: количество отзывов 5
# Количество Телефонов с Диагональю различных характеристик:
# Телефон Cubot: количество отзывов 8
# Количество Телефонов с Диагональю различных характеристик:
# Телефон Oscal: количество отзывов 1

# %%
#Функция для перебора продуктов по диагоналям, ценам и кампаниям
def show_difference_in_diag_with_clusters(df):
    for n in range(0,3):
        #Копирование датасета по кампаниям
        df_com = df[df["kmeans_4"] == n]
        print("Количество Телефонов c Диагональю различных характеристик:")
        print("{}: {}".format(n,len(df_com[df_com["kmeans_4"] == n]))),
        sns.scatterplot(df_com[(df_com["kmeans_4"] == n)],y='diag', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний, с камерами различных характеристик')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_diag_with_clusters(df)
# Out:
# Количество Телефонов c Диагональю различных характеристик:
# 0: 5
# Количество Телефонов c Диагональю различных характеристик:
# 1: 8
# Количество Телефонов c Диагональю различных характеристик:
# 2: 9

# %%
#Функция для перебора продуктов по ПЗУ, ценам и кампаниям
def show_difference_in_ROM_with_companies(df):
    for n in companies:
        #Копирование датасета по кампаниям
        df_com = df[df["name"] == n]
        print("Количество Телефонов с ПЗУ различных характеристик:")
        print("Телефон {}: количество отзывов {}".format(n,len(df_com[df_com["name"] == n]))),
        sns.scatterplot(df_com[(df_com["name"] == n)],y='ROM', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_ROM_with_companies(df)
# Out:
# Количество Телефонов с ПЗУ различных характеристик:
# Телефон Apple: количество отзывов 1
# Количество Телефонов с ПЗУ различных характеристик:
# Телефон Google: количество отзывов 1
# Количество Телефонов с ПЗУ различных характеристик:
# Телефон Blackview: количество отзывов 6
# Количество Телефонов с ПЗУ различных характеристик:
# Телефон Oukitel: количество отзывов 1
# Количество Телефонов с ПЗУ различных характеристик:
# Телефон Ulefone: количество отзывов 4
# Количество Телефонов с ПЗУ различных характеристик:
# Телефон Xiaomi: количество отзывов 5
# Количество Телефонов с ПЗУ различных характеристик:
# Телефон Cubot: количество отзывов 8
# Количество Телефонов с ПЗУ различных характеристик:
# Телефон Oscal: количество отзывов 1

# %%
#Функция для перебора продуктов по ПЗУ, ценам и кампаниям
def show_difference_in_ROM_with_clusters(df):
    for n in range(0,3):
        #Копирование датасета по кампаниям
        df_com = df[df["kmeans_4"] == n]
        print("Количество Телефонов c ПЗУ различных характеристик:")
        print("{}: {}".format(n,len(df_com[df_com["kmeans_4"] == n]))),
        sns.scatterplot(df_com[(df_com["kmeans_4"] == n)],y='ROM', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний, с камерами различных характеристик')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_ROM_with_clusters(df)
# Out:
# Количество Телефонов c ПЗУ различных характеристик:
# 0: 5
# Количество Телефонов c ПЗУ различных характеристик:
# 1: 8
# Количество Телефонов c ПЗУ различных характеристик:
# 2: 9

# %%
#Функция для перебора продуктов по батареям, ценам и кампаниям
def show_difference_in_bat_with_companies(df):
    for n in companies:
        #Копирование датасета по кампаниям
        df_com = df[df["name"] == n]
        print("Количество Телефонов с Батареями различных характеристик")
        print("Телефон {}: количество отзывов {}".format(n,len(df_com[df_com["name"] == n]))),
        sns.scatterplot(df_com[(df_com["name"] == n)],y='bat', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_bat_with_companies(df)
# Out:
# Количество Телефонов с Батареями различных характеристик
# Телефон Apple: количество отзывов 1
# Количество Телефонов с Батареями различных характеристик
# Телефон Google: количество отзывов 1
# Количество Телефонов с Батареями различных характеристик
# Телефон Blackview: количество отзывов 6
# Количество Телефонов с Батареями различных характеристик
# Телефон Oukitel: количество отзывов 1
# Количество Телефонов с Батареями различных характеристик
# Телефон Ulefone: количество отзывов 4
# Количество Телефонов с Батареями различных характеристик
# Телефон Xiaomi: количество отзывов 5
# Количество Телефонов с Батареями различных характеристик
# Телефон Cubot: количество отзывов 8
# Количество Телефонов с Батареями различных характеристик
# Телефон Oscal: количество отзывов 1

# %%
#Функция для перебора продуктов по батареям, ценам и кампаниям
def show_difference_in_bat_with_clusters(df):
    for n in range(0,3):
        #Копирование датасета по кампаниям
        df_com = df[df["kmeans_4"] == n]
        print("Количество Телефонов с Батареями различных характеристик:")
        print("{}: {}".format(n,len(df_com[df_com["kmeans_4"] == n]))),
        sns.scatterplot(df_com[(df_com["kmeans_4"] == n)],y='bat', x="price",alpha=0.9,label=str(n)).set(title='Цены кампаний, с камерами различных характеристик')
        plt.legend()
    plt.show()#Сделано для отображения всех графиков сразу, а не только одного

# %%
show_difference_in_bat_with_clusters(df)
# Out:
# Количество Телефонов с Батареями различных характеристик:
# 0: 5
# Количество Телефонов с Батареями различных характеристик:
# 1: 8
# Количество Телефонов с Батареями различных характеристик:
# 2: 9

# %%
"""

Характеристики значительно сказываются на конечной цене, однако в ограниченном значении.
Большую играет роль реклама а так-же имя бренда.
Наибольшую разницу в ценах приносит именно батарея, ибо аккумуляторы с большим объемом -
- сказываются на стоимости телефона больше всего.

"""
# Out:
# '\n\nХарактеристики значительно сказываются на конечной цене, однако в ограниченном значении.\nБольшую играет роль реклама а так-же имя бренда.\nНаибольшую разницу в ценах приносит именно батарея, ибо аккумуляторы с большим объемом -\n- сказываются на стоимости телефона больше всего.\n\n'
