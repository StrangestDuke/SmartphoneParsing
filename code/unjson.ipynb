# %%
import json

# %%
with open("stuff.json", encoding="utf-8") as f:
        stuff = json.load(f)

# %%
for i in stuff["result"]:
    print("{}:{}".format(i['username'],i['password']))
# Out:
# rnbrzk376:3Aq3=&ol/z9b
# qgregi469:V/L/(k7?CD?:
# twwlya809:o:K,aCyU^&9-
# xvkapt724:gfg<*8Zcr5+2
# norsdg588:s*Y}:{<UX3a[
# qdvkxn609:ZF,c:$ZK&qyx
# kyevad521:(HKZUjl=5-w^
# ntjmrd531:g?99/xWi"dxM
# ruliij835:o)X"`NcRF{gt
# aombim876:r\OBG,xl5Phn
# mzjwfy628:V%R88?X;V*GO
# octcsf688:n!]=t,=lXF$d
# cphzhr790:R$:"_3_yHqh|
# bvvusk588:JKNN5?yGWOLH
# avbrnz875:&0gW-w@ZS'1v
# qabhcz230:v>6HU}<`@>Bh
# hettgo194:ZN/JgHw9(Z6V
# onhwzi601:5T[NJZ,a|B$7
# amnxkm794:ZRFd?W4BF.:\
# iorjrb906:nkd)c!%WQ!mL
# zulvdn883:$Yz32ji=z>^_
# qhjoje802:|O;~sPYK>nK/
# kbrdrn830:`?z41|~bYs{2
# tfeibu533:3=d=dg^-4:2m
# rfases363:u*5"s0E!U]\#
# ddgdig163:`s5,63+|t]?z
# spcbxn811:??u*VES9.c-!
# ierkio925:4;^Um(M\MU0|
# dsxkjo766:^4Xa(("0%|!e
# acvecv302:_pw".Al<.Ul*
# mzojpj645:I{^m|lAv!U|3
# upnsya528:^J'rV#po|s@[
# bghdut992:r`?yF>qzdr[=
# xaieyv482:qys!jgCY/ovT
# tzpfyr433:?5feACNRpds-
# ntpyus595:G4vPOl+z(#8w
# kupmcw627:=<|0V[k,gCk~
# hamewp268:P\JCum'V5@B|
# jhebxf388:cf4,u("D\/p;
# hdabzr669:;*qKLc;U+pr$
# ...
